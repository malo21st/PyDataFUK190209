# %% [markdown]
# <img src="img/PyDataLT1.png">

# %% [markdown]
# <img src="img/PyDataLT2.png">

# %% [markdown]
# <img src="img/PyDataLT3.png">

# %% [markdown]
# # データ
# - 自治体オープンデータ（福岡県）
#  - https://ckan.open-governmentdata.org/dataset/401000_kenseiyouran_jikeiretsu
#
#
# - ３　年齢別、男女別人口の推移　（エクセル）
#  - https://ckan.open-governmentdata.org/dataset/90a2e0fd-e466-4526-8e8d-c3d7e1293b82/resource/2abde841-8d4b-468e-8ed5-bd51d6967076/download/972.xls
#
# <img src="img/972_0.png">

# %% [markdown]
# ---
#
# # 入力（データの読込）　import pandas as pd
# - **pd.read_excel()**　pd.read_csv()　pd.read_json()　pd.read_html()

# %%
import pandas as pd

#URL = 'https://ckan.open-governmentdata.org/dataset/90a2e0fd-e466-4526-8e8d-c3d7e1293b82/resource/2abde841-8d4b-468e-8ed5-bd51d6967076/download/972.xls'
#df = pd.read_excel(URL)

df = pd.read_excel('972.xls')

# %%
print(df.shape)
df.head(20)
# Out:
# (136, 37)
#    ３　年齢別、男女別人口の推移 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             年　齢      昭和30年        NaN        NaN      昭和35年        NaN
# 2             NaN         総数          男          女         総数          男
# 3        総　　　　　　数          人          人          人          人          人
# 4             NaN    3859764    1895365    1964399    4006679    1954636
# 5            年少人口    1325668     675264     650404    1257355     641805
# 6       （0～14歳人口）        NaN        NaN        NaN        NaN        NaN
# 7          生産年齢人口    2355630    1145811    1209819    2541467    1224426
# 8      （15～64歳人口）        NaN        NaN        NaN        NaN        NaN
# 9            老年人口     178439      74276     104163     207857      88405
# 10      （65歳以上人口）        NaN        NaN        NaN        NaN        NaN
# 11           0～4歳     430793     219838     210955     340946     174395
# 12            0　歳      76621      39393      37228      67207      34588
# 13            1　歳      78648      40090      38558      69854      35746
# 14            2　歳      85776      43666      42110      68023      34689
# 15            3　歳      90097      45895      44202      65238      33403
# 16            4　歳      99651      50794      48857      70624      35969
# 17          5歳～9歳     500266     255505     244761     422558     215315
# 18            5　歳     104249      53154      51095      75255      38613
# 19            6　歳     117572      60033      57539      77124      39281
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 27  \
# 0         NaN        NaN        NaN        NaN     ...             NaN
# 1         NaN      昭和40年        NaN        NaN     ...             NaN
# 2           女         総数          男          女     ...               女
# 3           人          人          人          人     ...               人
# 4     2052043    3964611    1911317    2053294     ...         2575868
# 5      615550    1040391     528899     511492     ...          398301
# 6         NaN        NaN        NaN        NaN     ...             NaN
# 7     1317041    2678982    1275955    1403027     ...         1735974
# 8         NaN        NaN        NaN        NaN     ...             NaN
# 9      119452     245238     106463     138775     ...          439140
# 10        NaN        NaN        NaN        NaN     ...             NaN
# 11     166551     314309     160122     154187     ...          116132
# 12      32619      65652      33353      32299     ...           22813
# 13      34108      62944      32147      30797     ...           23181
# 14      33334      62275      31818      30457     ...           22976
# 15      31835      61623      31227      30396     ...           23373
# 16      34655      61815      31577      30238     ...           23789
# 17     207243     323228     164452     158776     ...          129643
# 18      36642      63044      32220      30824     ...           24081
# 19      37843      66342      33691      32651     ...           25219
#
#    Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1        平成12年         NaN         NaN       平成17年         NaN         NaN
# 2           総数           男           女          総数           男           女
# 3            人           人           人           人           人           人
# 4      5015699     2388824     2626875     5049908     2394094     2655814
# 5       742740      379971      362769      701195      358625      342570
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7      3393080     1653193     1739887     3326610     1619535     1707075
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9       870290      349367      520923      997798      400902      596896
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# 11      233014      119196      113818      223175      114326      108849
# 12       46254       23733       22521       42798       21840       20958
# 13       45490       23293       22197       43647       22324       21323
# 14       47227       24180       23047       44482       22844       21638
# 15       46994       24000       22994       45701       23370       22331
# 16       47049       23990       23059       46547       23948       22599
# 17      241704      123648      118056      235557      120496      115061
# 18       47899       24504       23395       46840       24142       22698
# 19       48056       24565       23491       46448       23753       22695
#
#    Unnamed: 34 Unnamed: 35 Unnamed: 36
# 0          NaN         NaN         NaN
# 1        平成22年         NaN         NaN
# 2           総数           男           女
# 3            人           人           人
# 4      5071968     2393965     2678003
# 5       684124      349867      334257
# 6          NaN         NaN         NaN
# 7      3227932     1568816     1659116
# 8          NaN         NaN         NaN
# 9      1123376      454694      668682
# 10         NaN         NaN         NaN
# 11      222872      113985      108887
# 12       45031       22957       22074
# 13       44248       22540       21708
# 14       45359       23183       22176
# 15       44853       22988       21865
# 16       43381       22317       21064
# 17      224952      115156      109796
# 18       43011       22069       20942
# 19       44286       22618       21668
#
# [20 rows x 37 columns]

# %% [markdown]
# ---
#
# # 入力（前処理）　df  DataFrame
# - **df.iloc[ ]　df.T**　df.loc[ ]　df.[df[0].str.contains("〜")==True]

# %%
# python2　　type(range(10)) => <type 'list'>
# python3　　type(range(10)) => <type 'range'>

raw = list(range(11,70,6)) + list(range(72,134,6))  # [11, 17, ..., 65, 72, 78, ..., 132]
col = list(range(2,36,3))                           # [2, 5, 8, 11, ..., 32, 35 ] 
df_male_temp = df.iloc[raw, col]

print(df_male_temp.shape)
df_male_temp        # 行：年代別の人口　，列：年
# Out:
# (21, 12)
#     Unnamed: 2 Unnamed: 5 Unnamed: 8 Unnamed: 11 Unnamed: 14 Unnamed: 17  \
# 11      219838     174395     160122      167160      189283      174058
# 17      255505     215315     164452      155888      169076      193736
# 23      199921     252095     204325      159361      155770      170806
# 29      182519     192136     222635      189236      163987      164371
# 35      179190     164239     156178      192552      179032      163346
# 41      168310     172440     149916      152689      195751      177936
# 47      127438     162649     161697      148490      160789      204410
# 53      101955     122771     151319      154568      149690      162739
# 59      100532      97701     113398      142205      153587      149007
# 65       90300      95990      90498      107321      140465      150130
# 72       79770      84908      88490       85158      103669      135669
# 78       66817      72684      77680       81276       80595       99483
# 84       48980      58908      64144       69513       76153       75366
# 90       33575      40584      48960       54482       61597       68223
# 96       21536      25377      30860       38397       44497       51376
# 102      12530      13849      16669       21052       27637       33027
# 108       5038       6439       7035        9102       12408       17057
# 114       1339       1819       2399        2810        3932        5733
# 120        244        309        505         713         803        1228
# 126         12         27         33          58          98         139
# 132          2          1          2           2           5           9
#
#     Unnamed: 20 Unnamed: 23 Unnamed: 26 Unnamed: 29 Unnamed: 32 Unnamed: 35
# 11       157203      132985      121318      119196      114326      113985
# 17       175645      157339      136136      123648      120496      115156
# 23       194270      175535      159415      137127      123803      120726
# 29       175801      202537      186825      168237      145375      130715
# 35       158166      167932      202867      187096      165977      137098
# 41       149327      137096      151423      182659      162982      144669
# 47       179764      147853      143225      154561      180072      162410
# 53       203805      177590      150964      144397      153701      181228
# 59       161004      201040      180116      151149      143823      155111
# 65       145615      156791      202534      178827      149157      143909
# 72       145315      141058      156301      198849      175530      148511
# 78       129900      138857      138820      152774      194285      173417
# 84        93959      122917      133421      134644      148633      191748
# 90        68617       86518      113717      123872      126994      141785
# 96        58800       59781       76228      100770      110998      115680
# 102       39772       46531       48176       63869       84227       93940
# 108       21729       26589       32130       35164       47598       63198
# 114        8584       11291       14165       18600       20952       28784
# 120        1989        3068        4264        5930        8238        8984
# 126         270         427         698        1066        1727        2094
# 132          22          27          56          96         168         229

# %%
df_male = df_male_temp.T

print(df_male.shape)
df_male.tail()        # 行：年　，列：年代別の人口
# Out:
# (12, 21)
#                 11      17      23      29      35      41      47      53   \
# Unnamed: 23  132985  157339  175535  202537  167932  137096  147853  177590
# Unnamed: 26  121318  136136  159415  186825  202867  151423  143225  150964
# Unnamed: 29  119196  123648  137127  168237  187096  182659  154561  144397
# Unnamed: 32  114326  120496  123803  145375  165977  162982  180072  153701
# Unnamed: 35  113985  115156  120726  130715  137098  144669  162410  181228
#
#                 59      65  ...      78      84      90      96     102  \
# Unnamed: 23  201040  156791 ...   138857  122917   86518   59781  46531
# Unnamed: 26  180116  202534 ...   138820  133421  113717   76228  48176
# Unnamed: 29  151149  178827 ...   152774  134644  123872  100770  63869
# Unnamed: 32  143823  149157 ...   194285  148633  126994  110998  84227
# Unnamed: 35  155111  143909 ...   173417  191748  141785  115680  93940
#
#                108    114   120   126  132
# Unnamed: 23  26589  11291  3068   427   27
# Unnamed: 26  32130  14165  4264   698   56
# Unnamed: 29  35164  18600  5930  1066   96
# Unnamed: 32  47598  20952  8238  1727  168
# Unnamed: 35  63198  28784  8984  2094  229
#
# [5 rows x 21 columns]

# %%
raw = list(range(11,70,6)) + list(range(72,134,6))
col = list(range(3,37,3))
df_female_temp = df.iloc[raw, col]
df_female = df_female_temp.T

type(df_female)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ---
#
# # 処理　import numpy as np
# - **n_ary = np.array(df.values)　n_ary1 + nary2　n_ary.sum(axis=int)**

# %%
import numpy as np

# pandasu.df => numpy.array
np_male   = np.array(df_male.values)
np_female = np.array(df_female.values)

type(np_female)
# Out:
# numpy.ndarray

# %%
# 男女の5歳階級別人口を合計する
np_total = np_male + np_female

print(np_total[3, 5], np_male[3, 5], np_female[3, 5])
# Out:
# 325396 152689 172707

# %%
# 年ごと（1955年〜2010年）の総人口を求める
np_yearly = np_total.sum(axis=1)

np_yearly
# Out:
# array([3859737, 4006679, 3964611, 4027416, 4290676, 4549326, 4717709,
#        4796103, 4926214, 5006110, 5025603, 5035432], dtype=object)

# %%
# ６５歳以上の高齢者人口
np_old_yearly = np_total[:, 13:].sum(axis=1)

np_old_yearly
# Out:
# array([178439, 207857, 245238, 292516, 354847, 426495, 499228, 597869,
#        728574, 870290, 997798, 1123376], dtype=object)

# %%
# 高齢化率　65歳以上が占める割合
np_old_rate = np_old_yearly / np_yearly * 100

np_old_rate
# Out:
# array([4.623087013441589, 5.187762733176279, 6.185676223972541,
#        7.263118585216924, 8.270188660248408, 9.374905205738168,
#        10.582000712634034, 12.465724776969969, 14.789735078500446,
#        17.38455607247943, 19.85429410162323, 22.309426480190776],
#       dtype=object)

# %% [markdown]
# ---
#
# # 出力　import matplotlib as plt   / gridspec
# - **gridspec.GridSpec()　ax = plt.subplot()　ax.plot()**
#
# - 人口ピラミッド　出典「**みんなのPython 第四版**」サンプルコード
# <img src="img/minpy4th.jpg">
#
# - **Chapter 12-04　日本の人口を視覚化する**　　人口ピラミッドを描く
#  - https://coreblog.org/ats/stuff/minpy_support/samplecodes04/samplecodes/Chapter12/12-04.html

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from matplotlib import gridspec

def show_pgraph(year, arr1, arr2, arr3,
                ymin, ymax, ydim=1):
    # 人口ピラミッドを表示する
    # 表示する人口のインデックスを得る
    idx = int((year-ymin)/ydim)
    # 人口ピラミッドと人口グラフのグリッドを生成
    gs = gridspec.GridSpec(2, 2, height_ratios=(3, 2))
    # グラフの配置を決める
    ax = [plt.subplot(gs[0, 0]),plt.subplot(gs[0, 1]),
          plt.subplot(gs[1, :])]
    # 男性の人口ピラミッドを描く
    ax[0].barh(range(0, 101, 5), arr1[idx], height=3)
    ax[0].set(ylim=(0, 105), xlim=(0, 300000))
    ax[0].invert_xaxis()
    ax[0].yaxis.tick_right()
    # 女性の人口ピラミッドを描く
    ax[1].barh(range(0, 101, 5), arr2[idx], height=3)
    ax[1].tick_params(labelleft=False)                   #  'off'  =>  False
    ax[1].set(ylim=(0, 105), xlim=(0, 300000))
    # 人口グラフを描き西暦に線を引く
    ax[2].plot(range(ymin, ymax+1, ydim), arr3, ls=":")
    ax[2].plot([year, year], [0, 5500000])

# %%
# show_pgraph(year, arr1, arr2, arr3, arr4, ymin, ymax, ydim=1)
show_pgraph(1955, np_male, np_female, np_yearly, 1955, 2010, 5)

# %% [markdown]
# ---
#
# # 出力　ipywidgets.interact, IntSlider, fixed
# - **interact(func, year=IntSlider( ), arr1=fixed(df), .....)**

# %%
# スライダを使って人口ピラミッドを動かす
from ipywidgets import interact, IntSlider, fixed

print("福岡県の人口ピラミッド　１９５５〜２０１０年")
t = interact(show_pgraph,
             year=IntSlider(min=1955, max=2010, step=5, description='西暦'),
             arr1=fixed(np_male),
             arr2=fixed(np_female),
             arr3=fixed(np_yearly),
             ymin=fixed(1955),
             ymax=fixed(2010), 
             ydim=fixed(5)
            )
# Out:
# 福岡県の人口ピラミッド　１９５５〜２０１０年
# interactive(children=(IntSlider(value=1955, description='西暦', max=2010, min=1955, step=5), Output()), _dom_cla…

# %% [markdown]
# ---
#
# ## デコレータでも使えます。 @interact(  )

# %%
# スライダを使って人口ピラミッドを動かす　　（デコレータ版）
from ipywidgets import interact, IntSlider, fixed

print("福岡県の人口ピラミッド　１９５５〜２０１０年")

selected_year=IntSlider(min=1955, max=2010, step=5, description='西暦')

@interact(year=selected_year, 
          arr1=fixed(np_male), 
          arr2=fixed(np_female), 
          arr3=fixed(np_yearly), 
          arr4=fixed(np_old_rate),
          ymin=fixed(1955), 
          ymax=fixed(2010), 
          ydim=fixed(5)
         )
def show_pgraph(year, arr1, arr2, arr3, arr4, ymin, ymax, ydim=1):
    # 人口ピラミッドを表示する
    # 表示する人口のインデックスを得る
    idx = int((year-ymin)/ydim)
    # 人口ピラミッドと人口グラフのグリッドを生成
    gs = gridspec.GridSpec(2, 2, height_ratios=(3, 2)) # , width_ratios=(1, 2)
    # グラフの配置を決める
    ax = [plt.subplot(gs[0, 0]),plt.subplot(gs[0, 1]),
          plt.subplot(gs[1, :])]
    # 男性の人口ピラミッドを描く
    ax[0].barh(range(0, 101, 5), arr1[idx], height=5, color='b', alpha=0.5, label="男性")
    ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x)))) # 三桁カンマの設定
    ax[0].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, loc: "{:>3}".format(int(y)))) 
    ax[0].set(ylim=(0, 105), xlim=(0, 300000))
    ax[0].invert_xaxis()
    ax[0].yaxis.tick_right()
    ax[0].legend(loc='upper left')
    # 女性の人口ピラミッドを描く
    ax[1].barh(range(0, 101, 5), arr2[idx], height=5, color='r', alpha=0.5, label="女性")
    ax[1].tick_params(labelleft=False)
    ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x)))) # 三桁カンマの設定
    ax[1].set(ylim=(0, 105), xlim=(0, 300000))
    ax[1].legend(loc='upper right')
    # 人口グラフを描き西暦に線を引く
    ax[2].yaxis.set_major_formatter(plt.FuncFormatter(lambda y, loc: "{:,}".format(int(y)))) # 三桁カンマの設定
    ax[2].set_ylim([0,5500000])
    ax[2].plot(range(ymin, ymax+1, ydim), arr3, ls="-", label="人口[人]", color="r", alpha=0.5)
    ax[2].legend(loc='center left')
    ax[2] = ax[2].twinx()
    ax[2].set_ylim([0,30])
    ax[2].plot(range(ymin, ymax+1, ydim), arr4, ls="-.", label="高齢化率[%]")
    ax[2].plot([year, year], [0, 5000000])
    ax[2].legend(loc='lower right')
# Out:
# 福岡県の人口ピラミッド　１９５５〜２０１０年
# interactive(children=(IntSlider(value=1955, description='西暦', max=2010, min=1955, step=5), Output()), _dom_cla…

# %% [markdown]
# ---
# # 今日、学んだこと　（まとめ）
# ---
# # **一連の処理は、Jupyter Notebook で完結できる。**
# ---
# <img src="img/summary.jpg">
#
# ---

# %% [markdown]
# <img src="img/PyDataLT5.png">
